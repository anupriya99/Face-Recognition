# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/ColabNotebooks"
# Out:
#  clooney.png			   'Copy of Untitled0.ipynb'   multiple.jpeg
# 'Copy of Copy of Untitled0.ipynb'  'Copy of Untitled1.ipynb'   Untitled1.ipynb
# 'Copy of Untitled0 (1).ipynb'	    george.jpeg		       women.jpeg

# %% [markdown]
# # New Section

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 41kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=c3fd7f9b4be79b29e738b8f65a3cfde12abbe1c25abfc5229bb7ca2a21013702
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data, exposure, io
import cv2


# read image
image = cv2.imread('/content/drive/My Drive/ColabNotebooks/clooney.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# feature description

fd , hog_image = hog(image, orientations=8, pixels_per_cell=(16,16), cells_per_block=(1,1), visualize=True, multichannel=True)

# plot Input and Hog image 

fig , (ax1,ax2) = plt.subplots(1,2,figsize=(8,4),sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image,cmap=plt.cm.gray)
ax1.set_title('Input image')

# rescale histogram for better display

hog_image_rescaled = exposure.rescale_intensity(hog_image , in_range=(0,10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled , cmap=plt.cm.gray)
ax2.set_title('Histogram of oriented gradients')

plt.show()

# %%
len(fd)
# Out:
# 5408

# %%
image.shape
# Out:
# (416, 416, 3)

# %% [markdown]
# # import face_recognition
#
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
# from matplotlib.patches import Circle
# import numpy as np
# import cv2
# %matplotlib inline

# %%
import face_recognition

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# import face_recognition
#
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
# from matplotlib.patches import Circle
# import numpy as np
# import cv2
# %matplotlib inline

# %%
image = cv2.imread('/content/drive/My Drive/ColabNotebooks/multiple.jpeg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print ("found {} face(s) in input image ." .format(number_of_faces))
# Out:
# found 3 face(s) in input image .

# %%
# get axis handle

plt.imshow(image)
ax = plt.gca()

# repeat for all faces found

for face_location in face_locations:
  # print the location of each face in this image. each face is a list of co-ordinates in (top,right,bottom,left )order
  top , right, bottom, left = face_location
  x,y,w,h = left , top, right, bottom
  print ("A face is located at pixel location Top:{}, Left:{}, Bottom:{}, Right:{}".format(x,y,w,h))

  #Let's draw box around the face

  rect = Rectangle((x,y),w-x,h-y,fill= False,color='red')
  ax.add_patch(rect)

# show output image
plt.show()
# Out:
# A face is located at pixel location Top:483, Left:82, Bottom:612, Right:211
# A face is located at pixel location Top:38, Left:96, Bottom:167, Right:225
# A face is located at pixel location Top:270, Left:92, Bottom:378, Right:199

# %%
import face_recognition

import matplotlib.pyplot as plt 
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle 
import numpy as np
import cv2 
# %matplotlib inline

# %%
image = cv2.imread('/content/drive/My Drive/ColabNotebooks/women.jpeg')
face_demo = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)


image = cv2.imread('/content/drive/My Drive/ColabNotebooks/george.jpeg')
clooney = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

image = cv2.imread('/content/drive/My Drive/ColabNotebooks/multiple.jpeg')
multiple = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
face_demo_encoding = face_recognition.face_encodings(face_demo)[0]
face_clooney_encoding = face_recognition.face_encodings(clooney)[0]
face_multiple_encoding = face_recognition.face_encodings(multiple)[0]

#Create database

known_face_encodings = [
                        face_demo_encoding,
                        face_clooney_encoding,
                        face_multiple_encoding
]

# %%
image
